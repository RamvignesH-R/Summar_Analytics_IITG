# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
data = pd.read_csv("./Cars.csv")
print(data.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
print(data.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print(data.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
print(data['name'])
data1=data
data=data.set_index('name')
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 398, dtype: object

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
print(data['mpg'].unique())
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
data['metric']=data['horsepower']/data['weight']
data=data.set_index('metric')

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
print(data1.columns)
print(data1.loc[data1['horsepower'].idxmax(),'name'])
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
# pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
print((data1['mpg']>=35).sum())
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here

print(data1[(data1['horsepower']>100) & (data1['weight']<3000)]['origin'].value_counts())
print(data1[(data1['horsepower']>100)&(data1['weight']<3000)]['origin'].value_counts().idxmax())
# Out:
# origin
# usa       9
# europe    8
# japan     6
# Name: count, dtype: int64
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
print(data1.columns)
print(data1[data1['origin']=='japan']['acceleration'].mean().round(2))
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
print(data1.groupby('model_year')['mpg'].mean().idxmax())
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
high_median_data=data1[data1['mpg']>data1['mpg'].median()]
high_median_data['ratio']=high_median_data['horsepower']/high_median_data['weight']
print(high_median_data[high_median_data['ratio']==high_median_data['ratio'].max()]['name'])
# Out:
# 23    bmw 2002
# Name: name, dtype: object
# C:\Users\hp\AppData\Local\Temp\ipykernel_2320\1320053265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_median_data['ratio']=high_median_data['horsepower']/high_median_data['weight']

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
avg_mpg=data1.groupby(['model_year','origin'])['mpg'].mean().reset_index()
plt.title('Average MPG over Years by Origin')
sns.lineplot(data=avg_mpg,x='model_year',y='mpg',hue='origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here

sns.scatterplot(data=data1,x='horsepower',y='weight',hue='origin',size='mpg',hue_order=['japan','europe','usa'])
plt.xlabel('Horse Power')
plt.ylabel('Weight')
plt.title('Scatter plot between Horse power and weight of cars over origin and mpg')
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
print("Car names that appear more than 1 model year")
print(data1['name'].value_counts()[data1['name'].value_counts()>1].index)
result=data1['name'].value_counts()[data1['name'].value_counts()>1].index
data1=data1[data1['name'].isin(result)]
print(data1)
d1=data1.groupby('name')['mpg'].agg(stdev='std',count='count',avg_mpg='mean').reset_index()
print(d1)
d1=d1[d1['stdev']<1.0]
sorted=d1.sort_values(by=['count','avg_mpg'],ascending=[False,False])
print("Consistent car models (low mpg variation over years):")
print(sorted[['name', 'count', 'avg_mpg']])
# Out:
# Car names that appear more than 1 model year
# Index(['ford pinto', 'ford maverick', 'amc matador', 'toyota corolla',
#        'peugeot 504', 'amc hornet', 'amc gremlin', 'chevrolet impala',
#        'chevrolet chevette', 'toyota corona', 'ford gran torino',
#        'plymouth fury iii', 'ford galaxie 500', 'chevrolet vega',
#        'pontiac catalina', 'plymouth duster', 'chevrolet nova',
#        'chevrolet citation', 'honda civic', 'dodge colt',
#        'chevrolet caprice classic', 'volkswagen dasher',
#        'buick estate wagon (sw)', 'chevrolet chevelle malibu',
#        'ford gran torino (sw)', 'chevrolet malibu', 'toyota corolla 1200',
#        'amc matador (sw)', 'opel 1900', 'ford country squire (sw)',
#        'datsun pl510', 'ford ltd', 'toyota mark ii', 'saab 99le', 'audi 100ls',
#        'opel manta', 'datsun 710', 'chevrolet chevelle malibu classic',
#        'fiat 128', 'plymouth valiant', 'buick century', 'subaru',
#        'honda civic cvcc', 'volkswagen rabbit', 'buick skylark',
#        'chevrolet monte carlo landau', 'subaru dl', 'vw rabbit',
#        'oldsmobile cutlass salon brougham', 'amc concord', 'dodge aspen',
#        'datsun 210', 'pontiac phoenix', 'mazda 626', 'honda accord',
#        'plymouth reliant'],
#       dtype='object', name='name')
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# ..    ...        ...           ...         ...     ...           ...
# 363  22.4          6         231.0       110.0    3415          15.8
# 372  27.0          4         151.0        90.0    2735          18.0
# 381  36.0          4         107.0        75.0    2205          14.5
# 382  34.0          4         108.0        70.0    2245          16.9
# 383  38.0          4          91.0        67.0    1965          15.0
#
#      model_year origin                       name     ratio
# 0            70    usa  chevrolet chevelle malibu  0.037100
# 5            70    usa           ford galaxie 500  0.045612
# 6            70    usa           chevrolet impala  0.050528
# 7            70    usa          plymouth fury iii  0.049861
# 8            70    usa           pontiac catalina  0.050847
# ..          ...    ...                        ...       ...
# 363          81    usa              buick century  0.032211
# 372          82    usa            pontiac phoenix  0.032907
# 381          82  japan               honda accord  0.034014
# 382          82  japan             toyota corolla  0.031180
# 383          82  japan                honda civic  0.034097
#
# [149 rows x 10 columns]
#                                  name     stdev  count    avg_mpg
# 0                         amc concord  3.464823      2  21.850000
# 1                         amc gremlin  1.290994      4  19.500000
# 2                          amc hornet  2.136001      4  19.375000
# 3                         amc matador  1.483240      5  15.700000
# 4                    amc matador (sw)  0.707107      2  14.500000
# 5                          audi 100ls  2.121320      2  21.500000
# 6                       buick century  3.818377      2  19.700000
# 7             buick estate wagon (sw)  2.050610      2  15.450000
# 8                       buick skylark  4.313351      2  23.550000
# 9           chevrolet caprice classic  2.466441      3  15.833333
# 10          chevrolet chevelle malibu  0.707107      2  17.500000
# 11  chevrolet chevelle malibu classic  1.060660      2  16.750000
# 12                 chevrolet chevette  1.293574      4  30.400000
# 13                 chevrolet citation  2.857155      3  26.766667
# 14                   chevrolet impala  1.414214      4  13.000000
# 15                   chevrolet malibu  5.303301      2  16.750000
# 16       chevrolet monte carlo landau  2.616295      2  17.350000
# 17                     chevrolet nova  3.511885      3  18.333333
# 18                     chevrolet vega  2.645751      3  22.000000
# 19                         datsun 210  6.363961      2  36.300000
# 20                         datsun 710  5.656854      2  28.000000
# 21                       datsun pl510  0.000000      2  27.000000
# 22                        dodge aspen  0.353553      2  18.850000
# 23                         dodge colt  1.126943      3  27.300000
# 24                           fiat 128  3.535534      2  26.500000
# 25           ford country squire (sw)  1.767767      2  14.250000
# 26                   ford galaxie 500  0.577350      3  14.333333
# 27                   ford gran torino  1.040833      3  14.833333
# 28              ford gran torino (sw)  0.707107      2  13.500000
# 29                           ford ltd  0.707107      2  13.500000
# 30                      ford maverick  3.420526      5  19.800000
# 31                         ford pinto  3.638910      6  22.916667
# 32                       honda accord  2.545584      2  34.200000
# 33                        honda civic  7.094599      3  31.666667
# 34                   honda civic cvcc  2.192031      2  34.550000
# 35                          mazda 626  0.212132      2  31.450000
# 36  oldsmobile cutlass salon brougham  2.828427      2  21.900000
# 37                          opel 1900  2.121320      2  26.500000
# 38                         opel manta  1.414214      2  25.000000
# 39                        peugeot 504  3.484729      4  23.550000
# 40                    plymouth duster  1.527525      3  21.666667
# 41                  plymouth fury iii  0.577350      3  14.333333
# 42                   plymouth reliant  1.979899      2  28.600000
# 43                   plymouth valiant  2.828427      2  20.000000
# 44                   pontiac catalina  1.154701      3  14.666667
# 45                    pontiac phoenix  4.596194      2  30.250000
# 46                          saab 99le  0.707107      2  24.500000
# 47                             subaru  4.454773      2  29.150000
# 48                          subaru dl  2.687006      2  31.900000
# 49                     toyota corolla  2.516347      5  31.120000
# 50                toyota corolla 1200  0.707107      2  31.500000
# 51                      toyota corona  3.119161      4  26.875000
# 52                     toyota mark ii  0.707107      2  19.500000
# 53                  volkswagen dasher  2.929733      3  27.166667
# 54                  volkswagen rabbit  0.353553      2  29.250000
# 55                          vw rabbit  8.838835      2  35.250000
# Consistent car models (low mpg variation over years):
#                          name  count    avg_mpg
# 26           ford galaxie 500      3  14.333333
# 41          plymouth fury iii      3  14.333333
# 50        toyota corolla 1200      2  31.500000
# 35                  mazda 626      2  31.450000
# 54          volkswagen rabbit      2  29.250000
# 21               datsun pl510      2  27.000000
# 46                  saab 99le      2  24.500000
# 52             toyota mark ii      2  19.500000
# 22                dodge aspen      2  18.850000
# 10  chevrolet chevelle malibu      2  17.500000
# 4            amc matador (sw)      2  14.500000
# 28      ford gran torino (sw)      2  13.500000
# 29                   ford ltd      2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
